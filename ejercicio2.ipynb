# %% [markdown]
# # SISD

# %%
import numpy as np
import time

# Creamos dos arrays grandes
a = np.random.rand(10000)
b = np.random.rand(10000)
c = np.empty(10000)

start = time.time()
for i in range(10000):
    c[i] = a[i] + b[i]
end = time.time()

print("Tiempo con bucle for:", end - start, "segundos")
# Out:
# Tiempo con bucle for: 0.0038738250732421875 segundos

# %% [markdown]
# # SIMD

# %%
start = time.time()
c = a + b  # Esta operación se realiza en paralelo internamente
end = time.time()

print("Tiempo con NumPy vectorizado:", end - start, "segundos")
# Out:
# Tiempo con NumPy vectorizado: 0.0007026195526123047 segundos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Generar 500 registros de logs simulados
np.random.seed(42)

# Lista de eventos de seguridad
eventos = ['login_success', 'login_failure', 'file_access', 'admin_login', 
           'password_change', 'firewall_block', 'suspicious_activity', 
           'malware_detected', 'port_scan']

# %%
# Generar timestamps para una semana
fechas = pd.date_range(start='2023-01-01', periods=7)
timestamps = []
for fecha in fechas:
    for hora in range(24):
        for _ in range(3):  # 3 eventos por hora aprox
            timestamps.append(fecha + pd.Timedelta(hours=hora) + 
                             pd.Timedelta(minutes=np.random.randint(60)))

# %%
print(fechas)
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
print(timestamps)
# Out:
# [Timestamp('2023-01-01 00:44:00'), Timestamp('2023-01-01 00:19:00'), Timestamp('2023-01-01 00:00:00'), Timestamp('2023-01-01 01:07:00'), Timestamp('2023-01-01 01:45:00'), Timestamp('2023-01-01 01:15:00'), Timestamp('2023-01-01 02:13:00'), Timestamp('2023-01-01 02:11:00'), Timestamp('2023-01-01 02:50:00'), Timestamp('2023-01-01 03:22:00'), Timestamp('2023-01-01 03:14:00'), Timestamp('2023-01-01 03:27:00'), Timestamp('2023-01-01 04:33:00'), Timestamp('2023-01-01 04:01:00'), Timestamp('2023-01-01 04:31:00'), Timestamp('2023-01-01 05:22:00'), Timestamp('2023-01-01 05:21:00'), Timestamp('2023-01-01 05:50:00'), Timestamp('2023-01-01 06:24:00'), Timestamp('2023-01-01 06:57:00'), Timestamp('2023-01-01 06:21:00'), Timestamp('2023-01-01 07:57:00'), Timestamp('2023-01-01 07:57:00'), Timestamp('2023-01-01 07:21:00'), Timestamp('2023-01-01 08:48:00'), Timestamp('2023-01-01 08:51:00'), Timestamp('2023-01-01 08:41:00'), Timestamp('2023-01-01 09:05:00'), Timestamp('2023-01-01 09:14:00'), Timestamp('2023-01-01 09:53:00'), Timestamp('2023-01-01 10:42:00'), Timestamp('2023-01-01 10:59:00'), Timestamp('2023-01-01 10:36:00'), Timestamp('2023-01-01 11:32:00'), Timestamp('2023-01-01 11:07:00'), Timestamp('2023-01-01 11:52:00'), Timestamp('2023-01-01 12:59:00'), Timestamp('2023-01-01 12:43:00'), Timestamp('2023-01-01 12:43:00'), Timestamp('2023-01-01 13:04:00'), Timestamp('2023-01-01 13:38:00'), Timestamp('2023-01-01 13:03:00'), Timestamp('2023-01-01 14:05:00'), Timestamp('2023-01-01 14:44:00'), Timestamp('2023-01-01 14:31:00'), Timestamp('2023-01-01 15:51:00'), Timestamp('2023-01-01 15:29:00'), Timestamp('2023-01-01 15:46:00'), Timestamp('2023-01-01 16:34:00'), Timestamp('2023-01-01 16:54:00'), Timestamp('2023-01-01 16:39:00'), Timestamp('2023-01-01 17:51:00'), Timestamp('2023-01-01 17:15:00'), Timestamp('2023-01-01 17:12:00'), Timestamp('2023-01-01 18:49:00'), Timestamp('2023-01-01 18:59:00'), Timestamp('2023-01-01 18:41:00'), Timestamp('2023-01-01 19:29:00'), Timestamp('2023-01-01 19:18:00'), Timestamp('2023-01-01 19:16:00'), Timestamp('2023-01-01 20:55:00'), Timestamp('2023-01-01 20:18:00'), Timestamp('2023-01-01 20:27:00'), Timestamp('2023-01-01 21:57:00'), Timestamp('2023-01-01 21:54:00'), Timestamp('2023-01-01 21:25:00'), Timestamp('2023-01-01 22:36:00'), Timestamp('2023-01-01 22:25:00'), Timestamp('2023-01-01 22:52:00'), Timestamp('2023-01-01 23:22:00'), Timestamp('2023-01-01 23:08:00'), Timestamp('2023-01-01 23:11:00'), Timestamp('2023-01-02 00:52:00'), Timestamp('2023-01-02 00:00:00'), Timestamp('2023-01-02 00:57:00'), Timestamp('2023-01-02 01:57:00'), Timestamp('2023-01-02 01:00:00'), Timestamp('2023-01-02 01:46:00'), Timestamp('2023-01-02 02:33:00'), Timestamp('2023-01-02 02:31:00'), Timestamp('2023-01-02 02:53:00'), Timestamp('2023-01-02 03:47:00'), Timestamp('2023-01-02 03:24:00'), Timestamp('2023-01-02 03:39:00'), Timestamp('2023-01-02 04:44:00'), Timestamp('2023-01-02 04:52:00'), Timestamp('2023-01-02 04:00:00'), Timestamp('2023-01-02 05:15:00'), Timestamp('2023-01-02 05:38:00'), Timestamp('2023-01-02 05:04:00'), Timestamp('2023-01-02 06:21:00'), Timestamp('2023-01-02 06:28:00'), Timestamp('2023-01-02 06:54:00'), Timestamp('2023-01-02 07:02:00'), Timestamp('2023-01-02 07:11:00'), Timestamp('2023-01-02 07:25:00'), Timestamp('2023-01-02 08:15:00'), Timestamp('2023-01-02 08:50:00'), Timestamp('2023-01-02 08:36:00'), Timestamp('2023-01-02 09:21:00'), Timestamp('2023-01-02 09:56:00'), Timestamp('2023-01-02 09:28:00'), Timestamp('2023-01-02 10:13:00'), Timestamp('2023-01-02 10:27:00'), Timestamp('2023-01-02 10:04:00'), Timestamp('2023-01-02 11:46:00'), Timestamp('2023-01-02 11:48:00'), Timestamp('2023-01-02 11:29:00'), Timestamp('2023-01-02 12:45:00'), Timestamp('2023-01-02 12:51:00'), Timestamp('2023-01-02 12:04:00'), Timestamp('2023-01-02 13:11:00'), Timestamp('2023-01-02 13:15:00'), Timestamp('2023-01-02 13:25:00'), Timestamp('2023-01-02 14:25:00'), Timestamp('2023-01-02 14:47:00'), Timestamp('2023-01-02 14:20:00'), Timestamp('2023-01-02 ...

# %%
# Ajustar al número de registros deseados
timestamps = timestamps[:500]

# Generar IPs aleatorias
def random_ip():
    return f"{np.random.randint(1, 256)}.{np.random.randint(1, 256)}.{np.random.randint(1, 256)}.{np.random.randint(1, 256)}"

# Usuarios del sistema
usuarios = ['admin', 'user1', 'user2', 'user3', 'system', 'guest', None]

# Generar datos simulados
data = {
    'timestamp': timestamps,
    'ip_origen': [random_ip() for _ in range(500)],
    'evento': np.random.choice(eventos, 500, p=[0.3, 0.2, 0.2, 0.05, 0.05, 0.08, 0.07, 0.03, 0.02]),
    'usuario': np.random.choice(usuarios, 500, p=[0.1, 0.2, 0.2, 0.2, 0.1, 0.1, 0.1]),
    'severidad': np.random.choice(['low', 'medium', 'high', 'critical'], 500, p=[0.5, 0.3, 0.15, 0.05]),
    'exitoso': np.random.choice([True, False], 500, p=[0.8, 0.2]),
}

# %%
len(timestamps)
# Out:
# 500

# %%
print(usuarios)
# Out:
# ['admin', 'user1', 'user2', 'user3', 'system', 'guest', None]

# %%
print(data)
# Out:
# {'timestamp': [Timestamp('2023-01-01 00:44:00'), Timestamp('2023-01-01 00:19:00'), Timestamp('2023-01-01 00:00:00'), Timestamp('2023-01-01 01:07:00'), Timestamp('2023-01-01 01:45:00'), Timestamp('2023-01-01 01:15:00'), Timestamp('2023-01-01 02:13:00'), Timestamp('2023-01-01 02:11:00'), Timestamp('2023-01-01 02:50:00'), Timestamp('2023-01-01 03:22:00'), Timestamp('2023-01-01 03:14:00'), Timestamp('2023-01-01 03:27:00'), Timestamp('2023-01-01 04:33:00'), Timestamp('2023-01-01 04:01:00'), Timestamp('2023-01-01 04:31:00'), Timestamp('2023-01-01 05:22:00'), Timestamp('2023-01-01 05:21:00'), Timestamp('2023-01-01 05:50:00'), Timestamp('2023-01-01 06:24:00'), Timestamp('2023-01-01 06:57:00'), Timestamp('2023-01-01 06:21:00'), Timestamp('2023-01-01 07:57:00'), Timestamp('2023-01-01 07:57:00'), Timestamp('2023-01-01 07:21:00'), Timestamp('2023-01-01 08:48:00'), Timestamp('2023-01-01 08:51:00'), Timestamp('2023-01-01 08:41:00'), Timestamp('2023-01-01 09:05:00'), Timestamp('2023-01-01 09:14:00'), Timestamp('2023-01-01 09:53:00'), Timestamp('2023-01-01 10:42:00'), Timestamp('2023-01-01 10:59:00'), Timestamp('2023-01-01 10:36:00'), Timestamp('2023-01-01 11:32:00'), Timestamp('2023-01-01 11:07:00'), Timestamp('2023-01-01 11:52:00'), Timestamp('2023-01-01 12:59:00'), Timestamp('2023-01-01 12:43:00'), Timestamp('2023-01-01 12:43:00'), Timestamp('2023-01-01 13:04:00'), Timestamp('2023-01-01 13:38:00'), Timestamp('2023-01-01 13:03:00'), Timestamp('2023-01-01 14:05:00'), Timestamp('2023-01-01 14:44:00'), Timestamp('2023-01-01 14:31:00'), Timestamp('2023-01-01 15:51:00'), Timestamp('2023-01-01 15:29:00'), Timestamp('2023-01-01 15:46:00'), Timestamp('2023-01-01 16:34:00'), Timestamp('2023-01-01 16:54:00'), Timestamp('2023-01-01 16:39:00'), Timestamp('2023-01-01 17:51:00'), Timestamp('2023-01-01 17:15:00'), Timestamp('2023-01-01 17:12:00'), Timestamp('2023-01-01 18:49:00'), Timestamp('2023-01-01 18:59:00'), Timestamp('2023-01-01 18:41:00'), Timestamp('2023-01-01 19:29:00'), Timestamp('2023-01-01 19:18:00'), Timestamp('2023-01-01 19:16:00'), Timestamp('2023-01-01 20:55:00'), Timestamp('2023-01-01 20:18:00'), Timestamp('2023-01-01 20:27:00'), Timestamp('2023-01-01 21:57:00'), Timestamp('2023-01-01 21:54:00'), Timestamp('2023-01-01 21:25:00'), Timestamp('2023-01-01 22:36:00'), Timestamp('2023-01-01 22:25:00'), Timestamp('2023-01-01 22:52:00'), Timestamp('2023-01-01 23:22:00'), Timestamp('2023-01-01 23:08:00'), Timestamp('2023-01-01 23:11:00'), Timestamp('2023-01-02 00:52:00'), Timestamp('2023-01-02 00:00:00'), Timestamp('2023-01-02 00:57:00'), Timestamp('2023-01-02 01:57:00'), Timestamp('2023-01-02 01:00:00'), Timestamp('2023-01-02 01:46:00'), Timestamp('2023-01-02 02:33:00'), Timestamp('2023-01-02 02:31:00'), Timestamp('2023-01-02 02:53:00'), Timestamp('2023-01-02 03:47:00'), Timestamp('2023-01-02 03:24:00'), Timestamp('2023-01-02 03:39:00'), Timestamp('2023-01-02 04:44:00'), Timestamp('2023-01-02 04:52:00'), Timestamp('2023-01-02 04:00:00'), Timestamp('2023-01-02 05:15:00'), Timestamp('2023-01-02 05:38:00'), Timestamp('2023-01-02 05:04:00'), Timestamp('2023-01-02 06:21:00'), Timestamp('2023-01-02 06:28:00'), Timestamp('2023-01-02 06:54:00'), Timestamp('2023-01-02 07:02:00'), Timestamp('2023-01-02 07:11:00'), Timestamp('2023-01-02 07:25:00'), Timestamp('2023-01-02 08:15:00'), Timestamp('2023-01-02 08:50:00'), Timestamp('2023-01-02 08:36:00'), Timestamp('2023-01-02 09:21:00'), Timestamp('2023-01-02 09:56:00'), Timestamp('2023-01-02 09:28:00'), Timestamp('2023-01-02 10:13:00'), Timestamp('2023-01-02 10:27:00'), Timestamp('2023-01-02 10:04:00'), Timestamp('2023-01-02 11:46:00'), Timestamp('2023-01-02 11:48:00'), Timestamp('2023-01-02 11:29:00'), Timestamp('2023-01-02 12:45:00'), Timestamp('2023-01-02 12:51:00'), Timestamp('2023-01-02 12:04:00'), Timestamp('2023-01-02 13:11:00'), Timestamp('2023-01-02 13:15:00'), Timestamp('2023-01-02 13:25:00'), Timestamp('2023-01-02 14:25:00'), Timestamp('2023-01-02 14:47:00'), Timestamp('2023-01-02 14:20:00'), Timesta ...
#        'suspicious_activity', 'login_success', 'login_success',
#        'file_access', 'login_failure', 'firewall_block',
#        'suspicious_activity', 'login_failure', 'login_success',
#        'password_change', 'login_success', 'firewall_block',
#        'login_failure', 'file_access', 'login_success', 'file_access',
#        'login_failure', 'file_access', 'login_success', 'admin_login',
#        'firewall_block', 'login_success', 'login_success',
#        'login_success', 'file_access', 'file_access', 'file_access',
#        'login_success', 'login_failure', 'file_access', 'login_failure',
#        'port_scan', 'login_success', 'file_access', 'login_failure',
#        'login_failure', 'admin_login', 'file_access', 'port_scan',
#        'login_success', 'login_success', 'admin_login', 'file_access',
#        'login_success', 'login_success', 'login_success',
#        'suspicious_activity', 'login_success', 'login_failure',
#        'login_success', 'login_failure', 'login_success', 'file_access',
#        'login_success', 'firewall_block', 'login_success', 'file_access',
#        'suspicious_activity', 'file_access', 'file_access',
#        'login_failure', 'login_failure', 'file_access', 'port_scan',
#        'file_access', 'file_access', 'admin_login', 'login_failure',
#        'login_success', 'file_access', 'malware_detected',
#        'login_success', 'file_access', 'login_success', 'file_access',
#        'login_success', 'login_failure', 'password_change',
#        'login_failure', 'file_access', 'password_change',
#        'suspicious_activity', 'login_success', 'login_failure',
#        'login_success', 'port_scan', 'suspicious_activity', 'file_access',
#        'firewall_block', 'file_access', 'file_access', 'login_success',
#        'password_change', 'login_success', 'firewall_block',
#        'password_change', 'admin_login', 'login_success', 'login_failure',
#        'login_success', 'login_failure', 'login_success',
#        'suspicious_activity', 'file_access', 'login_failure',
#        'login_failure', 'login_failure', 'file_access', 'file_access',
#        'suspicious_activity', 'login_failure', 'port_scan',
#        'firewall_block', 'login_success', 'suspicious_activity',
#        'login_success', 'firewall_block', 'login_failure',
#        'firewall_block', 'firewall_block', 'firewall_block',
#        'password_change', 'login_failure', 'login_success',
#        'login_failure', 'login_success', 'file_access', 'login_failure',
#        'malware_detected', 'file_access', 'firewall_block',
#        'login_success', 'firewall_block', 'suspicious_activity',
#        'login_failure', 'file_access', 'password_change', 'login_success',
#        'file_access', 'login_failure', 'login_success', 'login_failure',
#        'login_success', 'login_success', 'login_success',
#        'malware_detected', 'file_access', 'malware_detected',
#        'login_failure', 'login_failure', 'file_access', 'login_failure',
#        'login_success', 'file_access', 'login_success', 'file_access',
#        'file_access', 'login_success', 'login_success', 'password_change',
#        'login_failure', 'login_success', 'port_scan', 'login_success',
#        'file_access', 'port_scan', 'login_success', 'login_success',
#        'login_success', 'login_failure', 'login_success', 'file_access',
#        'login_success', 'file_access', 'port_scan', 'firewall_block',
#        'file_access', 'login_failure', 'file_access', 'file_access',
#        'login_failure', 'login_success', 'suspicious_activity',
#        'login_failure', 'login_success', 'login_failure', 'login_failure',
#        'firewall_block', 'admin_login', 'password_change',
#        'login_success', 'login_failure', 'login_failure', 'login_success',
#        'login_success', 'password_change', 'login_success', 'file_access',
#        'login_success', 'login_success', 'login_success',
#        'malware_detected', 'firewall_block', 'malware_detected',
#        'login_failure', 'login_success', 'file_access', 'login_failure',
#        'firewall_block', 'login_success', 'login_failure',
#        'login_success', 'login_failure', 'admin_login', 'login_failure',
#        'login_failure', 'login_failure', 'login_failure',
#        'password_change', 'suspicious_activity', 'malware_detected',
#        'password_change', 'login_failure', 'file_access', 'login_failure',
#        'login_success', 'firewall_block', 'login_success',
#        'suspicious_activity', 'login_failure', 'file_access',
#        'file_access', 'suspicious_activity', 'file_access', 'file_access',
#        'login_success', 'file_access', 'login_success', 'admin_login',
#        'file_access', 'file_access', 'login_success', 'login_success',
#        'admin_login', 'login_success', 'login_success', 'login_success',
#        'malware_detected', 'admin_login', 'login_failure',
#        'login_success', 'login_failure', 'password_change', 'file_access',
#        'login_success', 'login_success', 'login_success', 'file_access',
#        'password_change', 'login_success', 'login_success',
#        'login_success', 'malware_detected', 'login_success',
#        'password_change', 'file_access', 'login_failure', 'login_success',
#        'login_success', 'file_access', 'password_change', 'file_access',
#        'file_access', 'login_success', 'malware_detected',
#        'password_change', 'login_success', 'malware_detected',
#        'file_access', 'file_access', 'admin_login', 'firewall_block',
#        'file_access', 'login_success', 'login_failure',
#        'suspicious_activity', 'login_success', 'login_failure',
#        'login_failure', 'login_failure', 'file_access',
#        'suspicious_activity', 'login_success', 'login_success',
#        'login_success', 'suspicious_activity', 'file_access',
#        'login_success', 'firewall_block', 'firewall_block',
#        'firewall_block', 'suspicious_activity', 'login_success',
#        'password_change', 'login_failure', 'firewall_block',
#        'admin_login', 'password_change', 'file_access', 'login_success',
#        'file_access', 'port_scan', 'suspicious_activity', 'login_success',
#        'login_success', 'login_success', 'admin_login', 'firewall_block',
#        'login_success', 'file_access', 'firewall_block', 'admin_login',
#        'file_access', 'file_access', 'file_access', 'login_success',
#        'file_access', 'file_access', 'firewall_block', 'file_access',
#        'password_change', 'login_success', 'login_failure',
#        'login_success', 'login_success', 'admin_login', 'port_scan',
#        'login_success', 'login_failure', 'firewall_block',
#        'login_success', 'file_access', 'admin_login', 'file_access',
#        'login_success', 'login_failure', 'password_change', 'file_access',
#        'login_success', 'password_change', 'login_success', 'admin_login',
#        'login_success', 'malware_detected', 'login_failure',
#        'login_failure', 'login_success', 'login_failure',
#        'firewall_block', 'port_scan', 'login_failure', 'login_failure',
#        'admin_login', 'suspicious_activity', 'file_access',
#        'login_failure', 'login_failure', 'file_access', 'login_success',
#        'file_access', 'login_failure', 'password_change', 'login_success',
#        'file_access', 'login_failure', 'file_access', 'login_success',
#        'file_access', 'file_access', 'file_access', 'file_access',
#        'file_access', 'firewall_block', 'login_success', 'firewall_block',
#        'login_failure', 'login_success', 'login_success', 'login_failure',
#        'password_change', 'admin_login', 'password_change', 'file_access',
#        'login_failure', 'login_success', 'login_failure', 'login_failure',
#        'login_success', 'login_success', 'file_access', 'admin_login',
#        'port_scan', 'suspicious_activity', 'file_access', 'login_failure',
#        'file_access', 'password_change', 'login_success', 'login_failure',
#        'firewall_block', 'login_failure', 'file_access', 'file_access',
#        'login_success', 'login_failure', 'login_failure', 'login_success',
#        'login_success', 'firewall_block', 'login_success', 'file_access',
#        'login_success', 'suspicious_activity', 'login_success',
#        'login_failure', 'firewall_block', 'firewall_block',
#        'login_success', 'firewall_block', 'login_failure',
#        'login_failure', 'login_success', 'login_success', 'admin_login',
#        'login_failure', 'login_failure', 'admin_login', 'password_change',
#        'login_success', 'file_access', 'login_success', 'password_change',
#        'file_access', 'malware_detected', 'login_success',
#        'login_success', 'login_success', 'login_success', 'login_success',
#        'suspicious_activity', 'login_success', 'login_success',
#        'password_change', 'login_failure', 'password_change',
#        'login_success', 'login_failure', 'login_success', 'login_success',
#        'suspicious_activity', 'login_success', 'file_access',
#        'login_failure', 'login_failure', 'suspicious_activity',
#        'login_success', 'file_access', 'malware_detected', 'file_access',
#        'suspicious_activity', 'login_success', 'login_failure',
#        'login_success', 'admin_login', 'port_scan', 'login_success',
#        'file_access', 'login_success', 'file_access', 'login_failure',
#        'malware_detected', 'file_access', 'login_failure',
#        'login_success', 'login_success', 'login_success', 'login_success',
#        'firewall_block', 'file_access', 'file_access', 'login_success',
#        'firewall_block', 'admin_login', 'login_success', 'admin_login',
#        'file_access', 'login_success'], dtype='<U19'), 'usuario': array(['user2', 'user2', 'user1', None, 'guest', 'user3', 'user2',
#        'user2', 'user3', 'user3', 'admin', 'user3', 'guest', 'user2',
#        'admin', 'system', 'user1', 'user1', 'user1', 'user2', 'system',
#        'user3', 'user1', 'guest', 'guest', 'guest', 'user1', 'user2',
#        None, 'system', 'admin', 'admin', 'user2', None, 'user3', 'user2',
#        'user1', 'user3', 'guest', 'user2', 'system', None, 'user1',
#        'user3', 'user1', 'system', 'user3', 'user3', 'system', 'user2',
#        None, 'user3', 'user1', 'user3', 'system', 'user2', 'guest', None,
#        'user1', None, 'user1', 'user1', 'user1', 'guest', 'user3',
#        'user1', 'user2', 'user3', 'admin', 'guest', 'guest', 'user3',
#        None, 'user2', None, 'user3', 'user3', 'user1', 'guest', 'user2',
#        'user1', 'admin', 'user3', 'user3', 'system', 'guest', 'admin',
#        'system', 'user1', 'guest', 'guest', 'user3', 'system', 'user2',
#        'user2', 'guest', 'user2', 'user2', 'user2', 'guest', 'user2',
#        'user1', 'system', 'guest', 'user1', 'user1', 'user1', 'user2',
#        'user2', 'system', 'user3', 'user3', 'user2', 'guest', 'user2',
#        None, 'user3', 'user1', 'user3', 'user2', 'user3', 'admin',
#        'user1', 'guest', 'user1', 'guest', 'user1', 'user3', 'user3',
#        'user3', 'user2', 'user1', 'admin', 'user2', 'user3', None,
#        'guest', 'system', 'system', 'user3', 'user1', None, 'user3',
#        'user3', 'user1', 'user2', 'user2', 'guest', 'user3', 'user2',
#        None, 'user1', 'user2', 'admin', 'system', None, 'user1', 'guest',
#        'user1', None, 'system', 'guest', 'admin', None, 'system', 'user2',
#        'guest', 'user1', 'guest', 'user1', 'system', 'user3', 'admin',
#        'user1', 'admin', 'user2', 'user2', 'user3', 'user1', 'user1',
#        'system', 'admin', None, 'guest', 'user3', 'user3', 'guest',
#        'user1', 'admin', 'user1', 'system', 'admin', 'user3', None,
#        'guest', 'user3', 'admin', 'guest', 'user3', 'user1', 'admin',
#        None, 'user3', 'guest', 'guest', 'user3', 'user3', 'user2',
#        'user2', 'user2', 'system', 'user3', 'guest', 'user2', 'user3',
#        'user3', 'user3', 'system', 'user1', 'user3', 'user1', 'user2',
#        'user2', 'user3', None, 'user3', 'system', 'user3', 'user3',
#        'admin', 'user1', 'user2', 'user2', 'admin', 'user1', 'user1',
#        None, 'user2', 'user2', 'user1', 'user3', 'user1', 'user1',
#        'user3', 'admin', 'admin', 'user1', 'admin', 'user1', 'user2',
#        'guest', 'user3', 'user3', 'user1', None, 'user2', 'admin',
#        'user3', 'user1', 'user2', 'user3', 'guest', 'user2', 'system',
#        None, 'user1', 'user1', 'user2', 'user2', 'user2', None, 'system',
#        'user3', 'user2', 'guest', None, 'guest', 'admin', 'user3',
#        'admin', 'user1', 'admin', 'user3', 'user3', 'user1', 'user2',
#        'user2', 'user2', 'user1', 'user2', 'system', 'admin', 'admin',
#        'user2', None, 'user3', 'user3', 'user2', 'user3', 'admin',
#        'user3', None, 'user3', 'guest', 'system', 'user1', None, 'admin',
#        'user3', 'user1', 'admin', 'user2', 'user1', 'user2', 'user3',
#        'admin', 'user1', 'user3', 'user2', 'system', 'user3', 'guest',
#        'user3', 'user2', 'user3', 'user1', 'user2', 'system', 'user2',
#        'system', 'guest', 'guest', None, 'user2', 'user2', 'user3',
#        'user2', 'user3', 'system', 'user3', 'user2', 'user1', 'user2',
#        'user1', 'guest', 'user2', 'user1', 'admin', 'user3', 'user3',
#        'user2', 'admin', 'user2', 'user2', 'user3', 'user3', 'user2',
#        'user1', None, 'user2', 'user3', 'user1', 'user2', 'admin',
#        'user3', None, 'user2', 'admin', 'admin', 'user2', 'user1',
#        'admin', 'system', 'user2', 'user1', None, 'user1', None, 'user2',
#        'guest', 'user3', 'guest', None, 'user1', None, 'user2', 'user2',
#        'user2', 'user3', 'user1', 'user3', 'user3', 'system', 'guest',
#        'user2', 'user2', 'user1', 'user1', 'admin', 'user2', 'user1',
#        None, 'user3', 'user2', 'user3', 'user1', 'user2', 'user3',
#        'user2', 'user2', None, 'guest', 'user3', 'user3', 'user3',
#        'user1', 'user2', 'admin', 'user2', 'user3', 'user1', None, None,
#        'system', 'user3', 'guest', 'user1', 'system', 'user1', 'system',
#        'user1', 'guest', None, 'user1', 'user2', None, 'user2', 'guest',
#        'user3', 'user2', 'user1', 'user1', 'system', 'user2', 'user3',
#        'user2', 'user3', 'guest', None, 'user2', 'guest', 'system',
#        'user3', None, 'user1', 'user1', 'guest', 'user2', 'guest',
#        'guest', 'admin', 'guest', 'user2', 'user3', 'user3', None,
#        'admin', 'user2', 'user3', 'system', 'user3', 'user1', 'user1',
#        'user2', 'guest', 'user1', 'user1', None, 'admin', None, 'user3',
#        'guest', 'user1', 'admin', 'system', 'guest', 'system', 'user1',
#        'system', 'system', 'user3', 'system', 'guest', 'user3', 'admin',
#        'user2', 'admin', 'user2', 'user2', 'admin'], dtype=object), 'severidad': array(['low', 'low', 'high', 'high', 'low', 'critical', 'medium', 'low',
#        'low', 'medium', 'medium', 'medium', 'low', 'low', 'low', 'low',
#        'low', 'low', 'high', 'high', 'low', 'high', 'low', 'low', 'low',
#        'medium', 'critical', 'medium', 'low', 'medium', 'low', 'high',
#        'medium', 'low', 'medium', 'medium', 'low', 'medium', 'low',
#        'medium', 'high', 'high', 'medium', 'medium', 'low', 'medium',
#        'low', 'low', 'low', 'low', 'medium', 'low', 'medium', 'low',
#        'low', 'medium', 'low', 'low', 'medium', 'low', 'high', 'low',
#        'low', 'medium', 'low', 'low', 'low', 'low', 'high', 'low',
#        'medium', 'high', 'low', 'high', 'low', 'critical', 'low',
#        'medium', 'low', 'low', 'medium', 'medium', 'low', 'low', 'medium',
#        'medium', 'critical', 'medium', 'critical', 'medium', 'low', 'low',
#        'medium', 'medium', 'low', 'low', 'critical', 'medium', 'low',
#        'low', 'low', 'low', 'low', 'low', 'medium', 'low', 'high', 'high',
#        'low', 'medium', 'low', 'high', 'low', 'medium', 'medium', 'low',
#        'low', 'medium', 'medium', 'low', 'medium', 'low', 'medium', 'low',
#        'high', 'low', 'low', 'low', 'low', 'medium', 'low', 'high', 'low',
#        'low', 'low', 'low', 'low', 'low', 'low', 'low', 'medium',
#        'medium', 'low', 'low', 'critical', 'medium', 'medium', 'low',
#        'medium', 'medium', 'medium', 'critical', 'low', 'low', 'medium',
#        'high', 'low', 'low', 'low', 'low', 'medium', 'medium', 'low',
#        'low', 'low', 'low', 'medium', 'critical', 'high', 'low', 'high',
#        'medium', 'medium', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'medium', 'low', 'low', 'critical', 'high', 'medium',
#        'critical', 'medium', 'critical', 'low', 'low', 'low', 'low',
#        'low', 'medium', 'medium', 'medium', 'low', 'high', 'medium',
#        'low', 'medium', 'low', 'low', 'high', 'low', 'low', 'high',
#        'medium', 'low', 'low', 'low', 'medium', 'low', 'low', 'critical',
#        'medium', 'low', 'medium', 'medium', 'low', 'low', 'high', 'low',
#        'medium', 'low', 'low', 'low', 'low', 'low', 'low', 'high',
#        'critical', 'medium', 'high', 'low', 'critical', 'low', 'critical',
#        'critical', 'medium', 'critical', 'medium', 'low', 'low', 'medium',
#        'low', 'medium', 'critical', 'low', 'medium', 'high', 'high',
#        'critical', 'medium', 'critical', 'medium', 'low', 'low', 'medium',
#        'low', 'medium', 'medium', 'low', 'medium', 'medium', 'low', 'low',
#        'low', 'low', 'high', 'low', 'medium', 'low', 'low', 'high',
#        'medium', 'low', 'low', 'low', 'low', 'medium', 'low', 'low',
#        'low', 'high', 'critical', 'low', 'medium', 'low', 'low', 'medium',
#        'high', 'critical', 'medium', 'low', 'medium', 'low', 'medium',
#        'low', 'medium', 'low', 'low', 'high', 'low', 'medium', 'low',
#        'low', 'low', 'low', 'high', 'low', 'critical', 'medium', 'low',
#        'medium', 'medium', 'medium', 'low', 'low', 'high', 'high', 'high',
#        'low', 'medium', 'low', 'low', 'low', 'medium', 'low', 'low',
#        'high', 'low', 'low', 'low', 'high', 'medium', 'low', 'high',
#        'high', 'low', 'medium', 'medium', 'medium', 'low', 'high',
#        'medium', 'low', 'low', 'low', 'low', 'medium', 'low', 'low',
#        'medium', 'low', 'critical', 'low', 'low', 'low', 'low', 'low',
#        'medium', 'critical', 'low', 'medium', 'medium', 'high', 'low',
#        'low', 'low', 'medium', 'high', 'low', 'low', 'high', 'high',
#        'critical', 'medium', 'low', 'medium', 'medium', 'low', 'medium',
#        'medium', 'low', 'medium', 'medium', 'critical', 'low', 'low',
#        'medium', 'low', 'medium', 'medium', 'low', 'medium', 'medium',
#        'low', 'high', 'high', 'medium', 'medium', 'low', 'high', 'medium',
#        'medium', 'high', 'low', 'high', 'low', 'low', 'low', 'critical',
#        'high', 'medium', 'medium', 'medium', 'high', 'low', 'low', 'low',
#        'medium', 'medium', 'low', 'low', 'high', 'low', 'medium',
#        'critical', 'low', 'low', 'medium', 'high', 'medium', 'critical',
#        'low', 'medium', 'medium', 'high', 'low', 'high', 'medium', 'low',
#        'low', 'high', 'low', 'low', 'low', 'high', 'medium', 'medium',
#        'low', 'medium', 'medium', 'high', 'high', 'low', 'medium', 'low',
#        'medium', 'low', 'low', 'low', 'medium', 'low', 'medium', 'low',
#        'low', 'medium', 'low', 'low', 'medium', 'low', 'low', 'low',
#        'high', 'medium', 'medium', 'medium', 'low', 'low', 'medium',
#        'low', 'low', 'low', 'low', 'critical', 'low', 'medium', 'low',
#        'critical', 'low', 'low', 'medium', 'medium', 'low', 'low', 'low',
#        'low'], dtype='<U8'), 'exitoso': array([ True,  True,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True, False, False,
#         True,  True, False,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True, False,  True,
#         True, False,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False, False, False,
#        False, False,  True,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#        False,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True, False, False,  True,
#         True,  True, False, False,  True,  True,  True,  True,  True,
#        False,  True, False, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#        False, False,  True,  True,  True,  True,  True, False, False,
#         True,  True,  True, False, False,  True,  True, False,  True,
#         True, False,  True,  True,  True,  True, False,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True, False,  True, False,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True, False,
#        False,  True, False, False, False, False,  True,  True,  True,
#         True, False,  True,  True, False, False, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True, False,  True,  True,  True,  True,  True,
#         True, False, False,  True,  True,  True, False, False,  True,
#        False,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#         True, False, False, False,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False,  True,  True, False, False,  True,  True,
#         True, False, False,  True, False,  True, False,  True, False,
#         True,  True,  True, False, False, False, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True, False,
#         True,  True,  True,  True,  True])}

# %%
# Crear DataFrame
logs_df = pd.DataFrame(data)

# Configurar timestamp como índice
logs_df['timestamp'] = pd.to_datetime(logs_df['timestamp'])
logs_df = logs_df.sort_values('timestamp')

# Ahora creamos las visualizaciones
plt.figure(figsize=(15, 10))

# %%
# 1. Distribución de eventos por tipo
plt.subplot(2, 2, 1)
eventos_count = logs_df['evento'].value_counts()
sns.barplot(x=eventos_count.index, y=eventos_count.values)
plt.xticks(rotation=45, ha='right')
plt.title('Distribución de Eventos por Tipo')
plt.tight_layout()

# %%
# 2. Distribución de eventos por severidad
plt.subplot(2, 2, 2)
severidad_count = logs_df['severidad'].value_counts()
colors = {'low': 'green', 'medium': 'blue', 'high': 'orange', 'critical': 'red'}
plt.pie(severidad_count, labels=severidad_count.index, autopct='%1.1f%%',
        colors=[colors[sev] for sev in severidad_count.index])
plt.title('Distribución de Eventos por Severidad')
# Out:
# Text(0.5, 1.0, 'Distribución de Eventos por Severidad')

# %%
# 3. Actividad por hora del día
plt.subplot(2, 2, 3)
logs_df['hour'] = logs_df['timestamp'].dt.hour
hourly_count = logs_df.groupby('hour').size()
sns.lineplot(x=hourly_count.index, y=hourly_count.values)
plt.title('Actividad por Hora del Día')
plt.xlabel('Hora')
plt.ylabel('Número de Eventos')
# Out:
# Text(0, 0.5, 'Número de Eventos')

# %%
logs_df
# Out:
#               timestamp        ip_origen               evento usuario  \
# 2   2023-01-01 00:00:00  236.133.222.222       firewall_block   user1
# 1   2023-01-01 00:19:00     50.12.193.54          file_access   user2
# 0   2023-01-01 00:44:00    182.118.3.123     malware_detected   user2
# 3   2023-01-01 01:07:00   251.57.145.112  suspicious_activity    None
# 5   2023-01-01 01:15:00    229.85.142.66        login_success   user3
# ..                  ...              ...                  ...     ...
# 497 2023-01-07 21:27:00    36.84.196.118          admin_login   user2
# 495 2023-01-07 21:31:00    71.191.56.241          admin_login   user2
# 496 2023-01-07 21:33:00   170.189.42.184        login_success   admin
# 499 2023-01-07 22:07:00   120.173.106.47        login_success   admin
# 498 2023-01-07 22:30:00     7.54.129.172          file_access   user2
#
#     severidad  exitoso  hour
# 2        high     True     0
# 1         low     True     0
# 0         low     True     0
# 3        high     True     1
# 5    critical    False     1
# ..        ...      ...   ...
# 497       low     True    21
# 495    medium     True    21
# 496       low     True    21
# 499       low     True    22
# 498       low     True    22
#
# [500 rows x 7 columns]

# %%
# 4. Eventos por día y por severidad
plt.subplot(2, 2, 4)
logs_df['date'] = logs_df['timestamp'].dt.date
pivot_table = pd.crosstab(logs_df['date'], logs_df['severidad'])
pivot_table.plot(kind='bar', stacked=True, colormap='viridis')
plt.title('Eventos por Día y Severidad')
plt.xlabel('Fecha')
plt.ylabel('Número de Eventos')
plt.xticks(rotation=45)

plt.tight_layout()
plt.savefig('security_dashboard.png')

# %%
pivot_table
# Out:
# severidad   critical  high  low  medium
# date
# 2023-01-01         2    11   38      21
# 2023-01-02         4     6   41      21
# 2023-01-03         7     7   37      21
# 2023-01-04         9     8   35      20
# 2023-01-05         3    11   38      20
# 2023-01-06         5    12   29      26
# 2023-01-07         3     8   35      22

# %%
# Crear gráfico de actividad sospechosa
plt.figure(figsize=(12, 6))

# 5. Mapa de calor de actividad por hora y tipo de evento
logs_df['hour'] = logs_df['timestamp'].dt.hour
heatmap_data = pd.crosstab(logs_df['hour'], logs_df['evento'])
sns.heatmap(heatmap_data, cmap='YlOrRd', annot=True, fmt='d', cbar_kws={'label': 'Número de Eventos'})
plt.title('Eventos por Hora y Tipo')
plt.xlabel('Tipo de Evento')
plt.ylabel('Hora del Día')
plt.tight_layout()
plt.savefig('activity_heatmap.png')

# %%
# 6. Análisis de accesos fallidos por usuario
plt.figure(figsize=(10, 6))
failed_logins = logs_df[(logs_df['evento'] == 'login_failure') & (logs_df['exitoso'] == False)]
user_failures = failed_logins['usuario'].value_counts()
sns.barplot(x=user_failures.index.fillna('anónimo'), y=user_failures.values)
plt.title('Intentos de Login Fallidos por Usuario')
plt.xlabel('Usuario')
plt.ylabel('Número de Intentos Fallidos')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('failed_logins_by_user.png')

# %%
# 7. Línea de tiempo de eventos críticos
plt.figure(figsize=(12, 4))
critical_events = logs_df[logs_df['severidad'] == 'critical']
plt.scatter(critical_events['timestamp'], [1]*len(critical_events), c='red', s=100)
plt.yticks([])
plt.title('Línea de Tiempo de Eventos Críticos')
plt.xlabel('Fecha y Hora')
plt.tight_layout()
plt.savefig('critical_events_timeline.png')

print("Visualizaciones generadas correctamente. Revisa los archivos .png generados.")
# Out:
# Visualizaciones generadas correctamente. Revisa los archivos .png generados.
